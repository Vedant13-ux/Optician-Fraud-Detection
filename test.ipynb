# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

dataset= pd.read_csv('historical_data.csv', delimiter=';')
dataset.head()
# Out:
#          chaine_PS  dep_opti           ref_PS Etat_PEC  Prix_brute_M  \
# 0  386a6002b407d5e        92  a0597f6f7c6dbf2      FAC           300
# 1  386a6002b407d5e        34  cc915026207811c      FAC           150
# 2  386a6002b407d5e        75  a051c65c4b68741      FAC            90
# 3  386a6002b407d5e        75  ae1abc30bfffa8a      FAC            40
# 4  386a6002b407d5e        13  935f32ba55d1575      FAC           150
#
#    Remise_M  Prix_brute_VD  Remise_VD  Prix_brute_VG  Remise_VG  ...  \
# 0         0            120          0            120          0  ...
# 1         0            325          0            325          0  ...
# 2         0            140          0            140          0  ...
# 3         0              0          0              0          0  ...
# 4         0             15          0             15          0  ...
#
#   Prix_monture  Prix_verres  Prix_total  remise_verres  remise_montures  \
# ...
